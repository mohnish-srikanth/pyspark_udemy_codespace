# %%
# %run /workspaces/pyspark_udemy_codespace/setup/setup_env.ipynb
# %run /workspaces/pyspark_udemy_codespace/datadrames/spark_dataframe.ipynb
# %run /workspaces/pyspark_udemy_codespace/datatypes_and_schema/schema_on_read.ipynb
# %run /workspaces/pyspark_udemy_codespace/datatypes_and_schema/correcting_datatype.ipynb
# Out:
# 26/05/15 14:24:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark version: 4.1.1
# Database created OK
# Table created OK
# {"cut":"Ideal","color":"E","clarity":"SI2","carat":0.23,"depth":61.5,"price":326}
#
# {"cut":"Premium","color":"E","clarity":"SI1","carat":0.21,"depth":59.8,"price":326}
#
# {"cut":"Good","color":"E","clarity":"VS1","carat":0.23,"depth":56.9,"price":327}
#
# {"cut":"Premium","color":"I","clarity":"VS2","carat":0.29,"depth":62.4,"price":334}
#
# {"cut":"Good","color":"J","clarity":"SI2","carat":0.31,"depth":63.3,"price":335}
# Rows Loaded:  53940
# +-----+-------+-----+-------+-----+-----+
# |carat|clarity|color|    cut|depth|price|
# +-----+-------+-----+-------+-----+-----+
# | 0.23|    SI2|    E|  Ideal| 61.5|  326|
# | 0.21|    SI1|    E|Premium| 59.8|  326|
# | 0.23|    VS1|    E|   Good| 56.9|  327|
# | 0.29|    VS2|    I|Premium| 62.4|  334|
# ...
