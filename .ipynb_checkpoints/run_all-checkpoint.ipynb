# %%
# %run /pyspark_udemy_codespace/setup/setup_env.ipynb
# %run /pyspark_udemy_codespace/datadrames/spark_dataframe.ipynb
# %run /pyspark_udemy_codespace/datatypes_and_schema/schema_on_read.ipynb
# %run /pyspark_udemy_codespace/datatypes_and_schema/correcting_datatype.ipynb
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyspark in d:\pyspark_udemy_codespace\.venv\lib\site-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in d:\pyspark_udemy_codespace\.venv\lib\site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment Temurin-17.0.19+10 (build 17.0.19+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.19+10 (build 17.0.19+10, mixed mode, sharing)
#
# 3.5.1
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment Temurin-17.0.19+10 (build 17.0.19+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.19+10 (build 17.0.19+10, mixed mode, sharing)
#
# 3.5.1
# Spark version: 3.5.3
# Database created OK
# Table created OK
# {"cut":"Ideal","color":"E","clarity":"SI2","carat":0.23,"depth":61.5,"price":326}
#
# {"cut":"Premium","color":"E","clarity":"SI1","carat":0.21,"depth":59.8,"price":326}
#
# {"cut":"Good","color":"E","clarity":"VS1","carat":0.23,"depth":56.9,"price":327}
#
# {"cut":"Premium","color":"I","clarity":"VS2","carat":0.29,"depth":62.4,"price":334}
#
# {"cut":"Good","color":"J","clarity":"SI2","carat":0.31,"depth":63.3,"price":335}
#
# Rows Loaded:  53940
# +-----+-------+-----+-------+-----+-----+
# |carat|clarity|color|    cut|depth|price|
# +-----+-------+-----+-------+-----+-----+
# | 0.23|    SI2|    E|  Ideal| 61.5|  326|
# | 0.21|    SI1|    E|Premium| 59.8|  326|
# | 0.23|    VS1|    E|   Good| 56.9|  327|
# | 0.29|    VS2|    I|Premium| 62.4|  334|
# | 0.31|    SI2|    J|   Good| 63.3|  335|
# +-----+-------+-----+-------+-----+-----+
# only showing top 5 rows
#
# +-----+------------------+
# |color|         avg_price|
# +-----+------------------+
# |    J|  5323.81801994302|
# |    I| 5091.874953891553|
# |    H| 4486.669195568401|
# |    G| 3999.135671271697|
# |    F| 3724.886396981765|
# |    D|3169.9540959409596|
# |    E|3076.7524752475247|
# +-----+------------------+
#
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# | spark_db| diamonds|      false|
# +---------+---------+-----------+
#
# +-----+-------+-----+---------+-----+-----+
# |carat|clarity|color|      cut|depth|price|
# +-----+-------+-----+---------+-----+-----+
# | 0.23|    SI2|    E|    Ideal| 61.5|  326|
# | 0.21|    SI1|    E|  Premium| 59.8|  326|
# | 0.23|    VS1|    E|     Good| 56.9|  327|
# | 0.29|    VS2|    I|  Premium| 62.4|  334|
# | 0.31|    SI2|    J|     Good| 63.3|  335|
# | 0.24|   VVS2|    J|Very Good| 62.8|  336|
# | 0.24|   VVS1|    I|Very Good| 62.3|  336|
# | 0.26|    SI1|    H|Very Good| 61.9|  337|
# | 0.22|    VS2|    E|     Fair| 65.1|  337|
# | 0.23|    VS1|    H|Very Good| 59.4|  338|
# |  0.3|    SI1|    J|     Good| 64.0|  339|
# | 0.23|    VS1|    J|    Ideal| 62.8|  340|
# | 0.22|    SI1|    F|  Premium| 60.4|  342|
# | 0.31|    SI2|    J|    Ideal| 62.2|  344|
# |  0.2|    SI2|    E|  Premium| 60.2|  345|
# | 0.32|     I1|    E|  Premium| 60.9|  345|
# |  0.3|    SI2|    I|    Ideal| 62.0|  348|
# |  0.3|    SI1|    J|     Good| 63.4|  351|
# |  0.3|    SI1|    J|     Good| 63.8|  351|
# |  0.3|    SI1|    J|Very Good| 62.7|  351|
# +-----+-------+-----+---------+-----+-----+
# only showing top 20 rows
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'/datadrames/spark_dataframe.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().run_line_magic('run', '/pyspark_udemy_codespace/setup/setup_env.ipynb')
# ----> 2 get_ipython().run_line_magic('run', '/datadrames/spark_dataframe.ipynb')
#       3 get_ipython().run_line_magic('run', '/datatypes_and_schema/schema_on_read.ipynb')
#       4 get_ipython().run_line_magic('run', '/datatypes_and_schema/correcting_datatype.ipynb')
#
# Exception: File `'/datadrames/spark_dataframe.ipynb'` not found.
